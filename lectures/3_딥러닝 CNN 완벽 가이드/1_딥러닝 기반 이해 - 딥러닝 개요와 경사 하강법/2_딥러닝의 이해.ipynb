# %% [markdown]
# ## AI, Machine Learning, Deep Learning 정의

# %% [markdown]
# * 머신러닝
#     * 기호주의
#     * 확률주의
#     * 진화주의
#     * 유추주의
#     * 정형 데이터 기반, 데이터 마이닝 예측 분석
# * 딥러닝
#     * 연결주의(심층 신경망)
#         * 영상 인식
#         * 음성 인식
#         * 언어 인식
#         * 로보틱스

# %% [markdown]
# ### 딥러닝
# * 인간 뇌의 학습과 기억의 메커니즘을 모방

# %%
from IPython.display import Image
Image("image/image1.png")

# %% [markdown]
# * 연결을 통한 학습의 강화

# %%
Image("image/image2.png")

# %% [markdown]
# * 딥러닝이 학습하는 것

# %%
Image("image/image3.png")
