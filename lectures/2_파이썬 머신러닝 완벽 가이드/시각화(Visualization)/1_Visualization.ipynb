# %% [markdown]
# ### Python 시각화 Library
#
# * Matplotlib
# * Seaborn
# * Pandas ?...

# %% [markdown]
# ### 통계 시각화와 업무 시각화
#
# * **통계적인(Statistical) 시각화**
#     * **히스토그램**, 바이올린 플롯, 산포도, **바차트**, **분위**, 상관 히트맵
# * 업무 분석(Business Analysis) 시각화
#     * 바차트, 라인 플롯, 파이 차트, 영역 차트, 산포도, 방사형 차트, 버블 차트, 깔때기 차트
#
#
# * Seaborn, Matplotlib, Plotly

# %% [markdown]
# ### Matplotlib
#
# * Python Graph Visualization으로 가장 많이 사용되는 라이브러리.
# * Python Fisulzation에 많은 공헌을 함
# * 3차원 이상의 업력 시각화도 다양하게 지원
# * 그러나 직관적이지 못한 API로 인해 개발에 익숙해지는데 많은 시간이 필요하며 기본 설정 환경에서 현대적인 감각이 떨어지는 Visual 개선 필요

# %%
from IPython.display import Image

# %%
Image("img/matplotlib-component.png")

# %% [markdown]
# ### Seaborn
#
# * Matplotlib보다 쉽고, 예쁘게, Pandas와의 쉬운 연동
# * Matplotlib 기반으로 쉽게 작성됨. Matplotlib의 high level API라고 이해하면 편함.
# * Default 설정만으로 Matplotlib보다 수려한 Visual 제공하며 Pandas와 쉽게 연동
# * 그러나 Matplotlib를 어느정도 알고 있어야 함
